# %% [markdown]
# <a href="https://colab.research.google.com/github/rishab-1903/ML_projects/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  import pandas as pd
  car=pd.read_csv('/content/Quikr_car.csv')
  import matplotlib.pyplot as plt

# %%
 car.head()
# Out:
#    Unnamed: 0                                          Name     Label  \
# 0           0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1           1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2           2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3           3                          Hyundai Venue - 2019  PLATINUM
# 4           4                             Honda Jazz - 2017  PLATINUM
#
#     Location       Price   Kms_driven Fuel_type       Owner  Year  Company
# 0  Bangalore   ₹3,80,000  35,056 kms     Petrol         NaN  2015     Ford
# 1  Bangalore   ₹4,65,000  44,000 kms     Petrol         NaN  2016   Maruti
# 2  Bangalore  ₹13,50,000  42,917 kms     Petrol         NaN  2018  Hyundai
# 3    Chennai  ₹10,19,699  16,112 kms    Petrol    2nd Owner  2019  Hyundai
# 4       Pune   ₹7,13,499  30,988 kms    Petrol    2nd Owner  2017    Honda

# %%
car.shape
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1032 non-null   int64
#  1   Name        1032 non-null   object
#  2   Label       1032 non-null   object
#  3   Location    1030 non-null   object
#  4   Price       1032 non-null   object
#  5   Kms_driven  1032 non-null   object
#  6   Fuel_type   1032 non-null   object
#  7   Owner       740 non-null    object
#  8   Year        1032 non-null   int64
#  9   Company     1032 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 80.8+ KB

# %%
car['Price'].unique()
# Out:
# array(['₹3,80,000', '₹4,65,000', '₹13,50,000', '₹10,19,699', '₹7,13,499',
#        '₹3,91,099', '₹4,74,299', '₹12,52,999', '₹3,93,699', '₹7,30,899',
#        '₹3,43,099', '₹7,07,599', '₹6,88,899', '₹14,21,599', '₹3,99,999',
#        '₹14,73,299', '₹10,25,000', '₹7,35,000', '₹6,00,000', '₹8,00,000',
#        '₹7,00,000', '₹8,20,000', '₹1,95,000', '₹18,50,000', '₹8,07,499',
#        '₹5,22,999', '₹7,40,899', '₹11,41,999', '₹9,71,299', '₹6,40,999',
#        '₹6,76,199', '₹5,62,399', '₹5,80,899', '₹7,70,999', '₹5,31,399',
#        '₹3,67,299', '₹4,12,199', '₹14,60,099', '₹6,18,699', '₹4,85,000',
#        '₹8,90,000', '₹2,45,000', '₹9,45,000', '₹5,90,000', '₹4,95,000',
#        '₹4,75,000', '₹12,00,000', '₹4,90,199', '₹9,20,999', '₹5,54,399',
#        '₹4,08,999', '₹12,48,299', '₹6,36,099', '₹4,52,699', '₹7,04,399',
#        '₹5,53,599', '₹9,99,599', '₹6,84,699', '₹6,20,399', '₹5,49,899',
#        '₹8,12,899', '₹6,56,699', '₹7,25,000', '₹37,00,000', '₹3,65,000',
# ...

# %% [markdown]
# Owner nul values

# %%
backup=car.copy()

# %%
car=backup.copy()

# %%
 car['Price']=car['Price'].str.replace(',','')

# %%
car=car[car['Price']!='Ask For Price']

# %%
car['Price']=car['Price'].str.replace('₹','').astype(int)

# %%
car['Price']
# Out:
# 0        380000
# 1        465000
# 2       1350000
# 3       1019699
# 4        713499
#          ...
# 1027     229000
# 1028     275000
# 1029    1750000
# 1030    1750000
# 1031    1750000
# Name: Price, Length: 1026, dtype: int64

# %%
car['Price'].unique()
# Out:
# array([ 380000,  465000, 1350000, 1019699,  713499,  391099,  474299,
#        1252999,  393699,  730899,  343099,  707599,  688899, 1421599,
#         399999, 1473299, 1025000,  735000,  600000,  800000,  700000,
#         820000,  195000, 1850000,  807499,  522999,  740899, 1141999,
#         971299,  640999,  676199,  562399,  580899,  770999,  531399,
#         367299,  412199, 1460099,  618699,  485000,  890000,  245000,
#         945000,  590000,  495000,  475000, 1200000,  490199,  920999,
#         554399,  408999, 1248299,  636099,  452699,  704399,  553599,
#         999599,  684699,  620399,  549899,  812899,  656699,  725000,
#        3700000,  365000,  280000,  840000,  818599,  862399,  673599,
#         528899,  527999,  791699,  392999,  690199,  474699, 2019899,
#         562299, 1400999,  447599, 1814599,  920399,  390000,  650000,
#         575000,  525000, 1000000,  325000, 3000000,  343299, 1711499,
# ...

# %%
car.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1026 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1026 non-null   int64
#  1   Name        1026 non-null   object
#  2   Label       1026 non-null   object
#  3   Location    1024 non-null   object
#  4   Price       1026 non-null   int64
#  5   Kms_driven  1026 non-null   object
#  6   Fuel_type   1026 non-null   object
#  7   Owner       738 non-null    object
#  8   Year        1026 non-null   int64
#  9   Company     1026 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 88.2+ KB

# %%
car['Kms_driven']=car['Kms_driven'].str.replace(',','')

# %%
car['Kms_driven']=car['Kms_driven'].str.replace(' kms','').astype(int)

# %%
car['Kms_driven'].unique()
# Out:
# array([ 35056,  44000,  42917,  16112,  30988,  69163,  42859,  34919,
#         44940,  13687,  29848,  21426,  68177,  70650,  25730,  47096,
#        131000,  26000,  58460,  48000,  26600,  36000,  39500,  76000,
#         23698,  37860,  91830,  31172,   3243,   9616,  30249,  60875,
#         25740,  38587,   3108,  35353,  34748,   2359,  17814,  68934,
#         72600,  81000,  80000,  12000,   6000,  56000,  15840,  32482,
#        113779,  26150,  34555,  30880,  70423,  30232,  50077,  18482,
#         10246,  25021,  70646,  45490,  53306,  29000, 110000,  95000,
#        170000,  58000,  22000,  69215,  33340,   9783,  15110,   3399,
#         89310,  53148,  42020,  74594,   6110,  24346,  65668,  48644,
#         36877,  79673,  54352,  64000,  54000,  40000, 107000,  38000,
#         86000,  10000,  48658,  11998,  32513,  21372,  34178,  20547,
#         34731,  30536,  10205,  25483,  39113,  43152,   5325,  44705,
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1026 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1026 non-null   int64
#  1   Name        1026 non-null   object
#  2   Label       1026 non-null   object
#  3   Location    1024 non-null   object
#  4   Price       1026 non-null   int64
#  5   Kms_driven  1026 non-null   int64
#  6   Fuel_type   1026 non-null   object
#  7   Owner       738 non-null    object
#  8   Year        1026 non-null   int64
#  9   Company     1026 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 88.2+ KB

# %%
car['Name'].str.split(' ').str.slice(0,3).str.join(' ')
# Out:
# 0          Ford Figo Duratec
# 1        Maruti Suzuki Wagon
# 2          Hyundai Creta 1.6
# 3            Hyundai Venue -
# 4               Honda Jazz -
#                 ...
# 1027       Hyundai i10 Magna
# 1028      Maruti Suzuki Alto
# 1029    Jeep Compass Limited
# 1030    Jeep Compass Limited
# 1031    Jeep Compass Limited
# Name: Name, Length: 1026, dtype: object

# %%
car=car.drop(['Label'],axis=1)

# %%
car=car.drop(['Location'],axis=1)

# %%
car['Fuel_type']=car['Fuel_type'].str.replace(' ','')

# %%
car['Fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Electric', 'CNG', 'LPG', 'Petrol+CNG',
#        'Hybrid'], dtype=object)

# %%
car['Owner'].unique()
# Out:
# array([nan, ' 2nd Owner', ' 1st Owner', ' 3rd Owner'], dtype=object)

# %%
car=car[car['Owner']!=car['Owner'].isna()]

# %%
car['Owner']=car['Owner'].str.replace(' 1st Owner','1')
car['Owner']=car['Owner'].str.replace(' 2nd Owner','2')
car['Owner']=car['Owner'].str.replace(' 3rd Owner','3')

# %%
car['Owner']=car.dropna(subset=['Owner'], inplace=True)

# %%
car=car.drop(['Owner'],axis=1)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 738 entries, 3 to 1031
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  738 non-null    int64
#  1   Name        738 non-null    object
#  2   Price       738 non-null    int64
#  3   Kms_driven  738 non-null    int64
#  4   Fuel_type   738 non-null    object
#  5   Year        738 non-null    int64
#  6   Company     738 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 46.1+ KB

# %%
car.head()
# Out:
#    Unnamed: 0                                            Name    Price  \
# 3           3                            Hyundai Venue - 2019  1019699
# 4           4                               Honda Jazz - 2017   713499
# 5           5                              Hyundai i20 - 2013   391099
# 6           6  Maruti Suzuki Swift Dzire VXi 1.2 BS IV - 2015   474299
# 7           7               Toyota Corolla Altis VL AT - 2017  1252999
#
#    Kms_driven Fuel_type  Year  Company
# 3       16112    Petrol  2019  Hyundai
# 4       30988    Petrol  2017    Honda
# 5       69163    Diesel  2013  Hyundai
# 6       42859    Petrol  2015   Maruti
# 7       34919    Petrol  2017   Toyota

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 738 entries, 3 to 1031
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  738 non-null    int64
#  1   Name        738 non-null    object
#  2   Price       738 non-null    int64
#  3   Kms_driven  738 non-null    int64
#  4   Fuel_type   738 non-null    object
#  5   Year        738 non-null    int64
#  6   Company     738 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 46.1+ KB

# %%
car.describe()
# Out:
#         Unnamed: 0         Price     Kms_driven         Year
# count   738.000000  7.380000e+02     738.000000   738.000000
# mean    519.112466  6.803854e+05   42880.126016  2016.647696
# std     301.479845  3.803416e+05   28497.835676     2.298132
# min       3.000000  7.300000e+04     700.000000  2001.000000
# 25%     250.250000  4.471240e+05   22713.750000  2015.000000
# 50%     531.500000  5.730490e+05   36278.000000  2017.000000
# 75%     781.750000  7.819712e+05   58484.000000  2018.000000
# max    1031.000000  3.300000e+06  210000.000000  2022.000000

# %%
car['Price'].unique()
# Out:
# array([1019699,  713499,  391099,  474299, 1252999,  730899,  343099,
#         707599,  688899, 1421599,  399999, 1473299,  600000,  800000,
#         807499,  522999,  740899, 1141999,  971299,  640999,  676199,
#         562399,  580899,  770999,  531399,  367299,  412199, 1460099,
#         618699,  485000,  245000, 1200000,  490199,  920999,  554399,
#         408999, 1248299,  636099,  452699,  704399,  553599,  999599,
#         684699,  620399,  549899,  812899,  656699,  725000,  818599,
#         862399,  673599,  528899,  527999,  791699,  392999,  690199,
#         474699, 2019899,  562299, 1400999,  447599, 1814599,  920399,
#         525000,  343299, 1711499,  918799,  526399,  881099, 1764199,
#         639199, 1917599,  466599, 1397699,  504399, 1920399,  917599,
#         319099,  484399,   73000, 1550000,  420000, 1595000,  573499,
#         879199,  733399,  967599, 1539299,  561499, 1042699, 1032099,
# ...

# %%
car['Price'].unique()
# Out:
# array([1019699,  713499,  391099,  474299, 1252999,  730899,  343099,
#         707599,  688899, 1421599,  399999, 1473299,  600000,  800000,
#         807499,  522999,  740899, 1141999,  971299,  640999,  676199,
#         562399,  580899,  770999,  531399,  367299,  412199, 1460099,
#         618699,  485000,  245000, 1200000,  490199,  920999,  554399,
#         408999, 1248299,  636099,  452699,  704399,  553599,  999599,
#         684699,  620399,  549899,  812899,  656699,  725000,  818599,
#         862399,  673599,  528899,  527999,  791699,  392999,  690199,
#         474699, 2019899,  562299, 1400999,  447599, 1814599,  920399,
#         525000,  343299, 1711499,  918799,  526399,  881099, 1764199,
#         639199, 1917599,  466599, 1397699,  504399, 1920399,  917599,
#         319099,  484399,   73000, 1550000,  420000, 1595000,  573499,
#         879199,  733399,  967599, 1539299,  561499, 1042699, 1032099,
# ...

# %%
car[car['Price']<6e6]
# Out:
#       Unnamed: 0                                            Name    Price  \
# 3              3                            Hyundai Venue - 2019  1019699
# 4              4                               Honda Jazz - 2017   713499
# 5              5                              Hyundai i20 - 2013   391099
# 6              6  Maruti Suzuki Swift Dzire VXi 1.2 BS IV - 2015   474299
# 7              7               Toyota Corolla Altis VL AT - 2017  1252999
# ...          ...                                             ...      ...
# 1023        1023                         Ford Figo Aspire - 2017   481399
# 1027        1027                    Hyundai i10 Magna 1.2 - 2014   229000
# 1029        1029          Jeep Compass Limited 2.0 Diesel - 2017  1750000
# 1030        1030          Jeep Compass Limited 2.0 Diesel - 2017  1750000
# 1031        1031          Jeep Compass Limited 2.0 Diesel - 2017  1750000
#
#       Kms_driven Fuel_type  Year  Company
# ...

# %%
car.reset_index()
# Out:
#      index  Unnamed: 0                                            Name  \
# 0        3           3                            Hyundai Venue - 2019
# 1        4           4                               Honda Jazz - 2017
# 2        5           5                              Hyundai i20 - 2013
# 3        6           6  Maruti Suzuki Swift Dzire VXi 1.2 BS IV - 2015
# 4        7           7               Toyota Corolla Altis VL AT - 2017
# ..     ...         ...                                             ...
# 733   1023        1023                         Ford Figo Aspire - 2017
# 734   1027        1027                    Hyundai i10 Magna 1.2 - 2014
# 735   1029        1029          Jeep Compass Limited 2.0 Diesel - 2017
# 736   1030        1030          Jeep Compass Limited 2.0 Diesel - 2017
# 737   1031        1031          Jeep Compass Limited 2.0 Diesel - 2017
#
#        Price  Kms_driven Fuel_type  Year  Company
# 0    1019699       16112    Petrol  2019  Hyundai
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 738 entries, 3 to 1031
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  738 non-null    int64
#  1   Name        738 non-null    object
#  2   Price       738 non-null    int64
#  3   Kms_driven  738 non-null    int64
#  4   Fuel_type   738 non-null    object
#  5   Year        738 non-null    int64
#  6   Company     738 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 46.1+ KB

# %%
 car.to_csv('Cleaned car.csv')
 car=car.reset_index()

# %%
car['Company'].unique()
# Out:
# array(['Hyundai', 'Honda', 'Maruti', 'Toyota', 'Jeep', 'Kia', 'Ford',
#        'Tata', 'Renault', 'Nissan', 'MG', 'Mahindra', 'Volkswagen',
#        'Skoda', 'Mercedes', 'BMW', 'Jaguar', 'Fiat', 'Datsun', 'Audi',
#        'Volvo', 'Chevrolet', 'Porsche'], dtype=object)

# %%
car=car.drop(columns='Unnamed: 0',axis=1)

# %%
car=car.drop(columns='index',axis=1)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        738 non-null    object
#  1   Price       738 non-null    int64
#  2   Kms_driven  738 non-null    int64
#  3   Fuel_type   738 non-null    object
#  4   Year        738 non-null    int64
#  5   Company     738 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 34.7+ KB

# %% [markdown]
# Model

# %%
X=car.drop(columns='Price')
y=car['Price']

# %%
y
# Out:
# 0      1019699
# 1       713499
# 2       391099
# 3       474299
# 4      1252999
#         ...
# 733     481399
# 734     229000
# 735    1750000
# 736    1750000
# 737    1750000
# Name: Price, Length: 738, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
car['Year'].unique()
# Out:
# array([2019, 2017, 2013, 2015, 2018, 2016, 2020, 2021, 2014, 2012, 2011,
#        2001, 2022, 2010, 2007])

# %%
 ohe=OneHotEncoder()
 ohe.fit(X[['Name','Company','Kms_driven','Fuel_type','Year']])
# Out:
# OneHotEncoder()

# %%
c_t= make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Name','Company','Kms_driven','Fuel_type','Year']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(c_t,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi Q3 - 2015', 'BMW 3 Series 320d - 2013',
#        'BMW 3 Series 320d Luxury Line - 2015',
#        'BMW 5 Series 523i Sedan - 2010', 'Chevrolet Sail 1.2 LS - 2013',
#        'Datsun Redi GO - 2017', 'Datsun Redi GO - 2018',
#        'Datsun Redi GO T O  - 2021', 'Fiat Linea Dynamic 1.3 - 201...
#        117000, 119571, 120399, 123920, 127971, 136000, 136082, 136381,
#        138716, 143147, 146782, 147819, 147960, 154104, 156442, 156931,
#        195000, 210000]),
#                                                                             array(['CNG', 'Diesel', 'Electric', 'Hybrid', 'Petrol', 'Petrol+CNG'],
#       dtype=object),
# ...

# %%
y_pred = pipe.predict(X_test)

# %%
y_pred
# Out:
# array([1393301.33003401,  388749.98830593,  466028.20538559,
#        1508306.01889084, 1759047.83912547, 1017434.35629653,
#         742848.69330295,  681172.28002482,  617607.70276866,
#         460383.61757485,  531681.03129206,  910483.47992884,
#         542872.03786474,  742722.68907265,  857710.74651069,
#         614202.5098424 ,  803706.52327699, 1229533.58452333,
#         646346.86010821,  483256.19628503,  514599.91140494,
#        1083229.80897014,  513632.84235817,  543701.70777356,
#         385983.59340175, 1124181.30313411,  508793.83724272,
#        1625817.30863306,  658740.51191402,  493281.03365773,
#         652705.07152412,  508793.83724272,  561966.85780107,
#         514599.91140494,  448958.8651403 ,  626173.13950796,
#         586105.486009  ,  673921.9498859 ,  513632.84235817,
#         948244.55303148,  505349.71757139,  482000.73998068,
#         733792.31661407,  438997.69506601,  614202.5098424 ,
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6407068693287722

# %%
a=['Ford Figo Aspire - 2017',16112,'Petrol',2019,	'Ford']

# %%
pipe.predict(pd.DataFrame([a],columns=['Name','Kms_driven','Fuel_type','Year','Company']))
# Out:
# array([769383.50432707])
